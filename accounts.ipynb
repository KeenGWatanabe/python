# %%
import pandas as pd
import numpy as np
#import data with dummy data to make months label non-header
graph = pd.read_csv('TB.csv')
# Inspect data
#print(graph.info())
graph
#without transposing, dataframe cannot plot
# Out:
#        dummy data      2301     2302       2303     2304       2305      2306  \
# 0          months       JAN      FEB        MAR      APR        MAY       JUN
# 1          ASSETS         0      NaN        NaN      NaN        NaN       NaN
# 2      Renovation         0        0          0        0          0         0
# 3   Motor Vehicle         0        0          0        0          0         0
# 4       Computers         0        0          0        0          0         0
# ..            ...       ...      ...        ...      ...        ...       ...
# 83        Capital         0        0          0        0          0         0
# 84       Reserves         0        0          0        0          0         0
# 85            NaN       NaN      NaN        NaN      NaN        NaN       NaN
# 86            NaN       NaN      NaN        NaN      NaN        NaN       NaN
# 87           NETT  22148.83  2483.36  -11821.27  14490.6  -12037.44  -3310.93
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
#drop() columns
#select column to target for deletion
df = pd.read_csv('TB.csv')

df.T
tb = pd.DataFrame(df.T)

tb
#after transpoing, also cannot plot, because the index is wrong
# Out:
#                 0       1           2              3          4          5   \
# dummy data  months  ASSETS  Renovation  Motor Vehicle  Computers  Equipment
# 2301           JAN       0           0              0          0          0
# 2302           FEB     NaN           0              0          0          0
# 2303           MAR     NaN           0              0          0          0
# 2304           APR     NaN           0              0          0          0
# 2305           MAY     NaN           0              0          0          0
# 2306           JUN     NaN           0              0          0          0
# 2307           JUL     NaN           0              0          0          0
# 2308           AUG     NaN           0              0          0          0
# 2309           SEP     NaN           0              0          0          0
# 2310           OCT     NaN           0              0          0          0
# ...

# %% [markdown]
# Explor Indexing

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'month': [2, 5, 8, 10], \
'year': [2017, 2019, 2018, 2019], \
 'sale': [60, 45, 90, 36]})
df
# Out:
#    month  year  sale
# 0      2  2017    60
# 1      5  2019    45
# 2      8  2018    90
# 3     10  2019    36

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'month': [2, 5, 8, 10], \
'year': [2017, 2019, 2018, 2019], \
 'sale': [60, 45, 90, 36]})
#set the 'month' column to be the index
df.set_index('month', inplace=True)
df
# Out:
#        year  sale
# month
# 2      2017    60
# 5      2019    45
# 8      2018    90
# 10     2019    36

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'month': [2, 5, 8, 10], \
'year': [2017, 2019, 2018, 2019], \
 'sale': [60, 45, 90, 36]})
#set the 'month' multi-index column to be the indexes
df.set_index(['year','month'], inplace=True)
df
# Out:
#             sale
# year month
# 2017 2        60
# 2019 5        45
# 2018 8        90
# 2019 10       36

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'month': [2, 5, 8, 10], \
'year': [2017, 2019, 2018, 2019], \
 'sale': [60, 45, 90, 36]})
#set the 'month' multi-index column to be the indexes
df1 = df.set_index(['year','month'], inplace=True)
df2 = df1.set_index([pd.Index([6, 7, 8, 9]), 'month'])
df2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 9
#       7 #set the 'month' multi-index column to be the indexes
#       8 df1 = df.set_index(['year','month'], inplace=True)
# ----> 9 df2 = df1.set_index([pd.Index([6, 7, 8, 9]), 'month'])
#      10 df2
#
# AttributeError: 'NoneType' object has no attribute 'set_index'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#this dataset is re-input from csv file as reference  
data = {'account': ['ASSETS', 'LIABILITIES', 'REVENUE', 'COST OF SALES', 'MARKETING','GENERAL EXPENSES','NETT'],
        'JAN': [0, 7014, 39127, 35467, 22487, 3321, 22148.83],
        'FEB': [0, 2581.0, 34234, 19321, 14092, 3304, 2483.36],
       }  
df = pd.DataFrame(data)

#melt down dataframe for plotting
tb = pd.melt(df, id_vars=["account"], value_vars=["JAN", "FEB"]) \
    .rename({"variable": "month"}, axis=1)
#plotting the graph with line
tb[tb["account"] == "REVENUE"].plot(x='month', y='value', kind='line')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
#drop() columns
#select column to target for deletion
df = pd.read_csv('TBT.csv')
df.plot(title='Profit/Loss analysis', x='months',y=['REVENUE','COST OF SALES','NETT'],kind='line')
plt.show()
